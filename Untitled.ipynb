# %%
import comb_equiv
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-b570f4a0c414> in <module>()
# ----> 1 import comb_equiv
#
# /Users/kahn/Dropbox/SHARED/Sam PhD/Translation Surfaces/Delauney Triangulations/comb_equiv/comb_equiv.py in <module>()
#       9 import itertools as it
#      10 import unittest
# ---> 11 from sage.all import *
#      12 import flatsurf
#      13 from collections import deque
#
# ImportError: No module named 'sage'
