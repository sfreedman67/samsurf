# %%
from context import bowman
import triangulation as trin
import sage.all
from sage.all import *

# %%
X = trin.Triangulation.ronen_l(44)
X.plot()
# Out:
# Graphics object consisting of 30 graphics primitives

# %%
cx = X.iso_delaunay_complex(500)
sum(r.plot() for r in cx)
# Out:
# Graphics object consisting of 3594 graphics primitives

# %%
F = X.generators_veech

# %%
F.plot()
# Out:
# Graphics object consisting of 974 graphics primitives

# %%
idr0 = (list(F.idrs))[0]
idr0.plot()
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
idr0 = (list(F.idrs))[2]
trin0 = idr0.triangulation
print(trin0.is_delaunay)
trin0.plot()
# Out:
# False
# True
# Graphics object consisting of 30 graphics primitives

# %%
trin0 = idr0.triangulation
print(trin0.is_delaunay)
trin0.plot()
# Out:
# False
# Graphics object consisting of 30 graphics primitives

# %%
m = matrix([[1, QQ(-1.9)], [0, QQ(0.5)]])
trin0_sheared = trin0.apply_matrix(m)

# %%
print(trin0_sheared.is_delaunay)
trin0_sheared.plot()
# Out:
# False
# Graphics object consisting of 30 graphics primitives
