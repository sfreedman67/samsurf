# %%
from context import bowman
import unfolding

# %%
rats = {QQ(-a/b) for b in range(1, 150) for a in range(1, 150)}

discriminants = [(c, (4 * c**2 + 1).numerator()) for c in rats]
for d in sorted(discriminants, key=lambda x: x[1]):
    print(d)
# Out:
# (-1/2, 2)
# (-1/4, 5)
# (-1, 5)
# (-1/6, 10)
# (-3/2, 10)
# (-1/3, 13)
# (-3/4, 13)
# (-1/8, 17)
# (-2, 17)
# (-2/3, 25)
# (-3/8, 25)
# (-1/10, 26)
# (-5/2, 26)
# (-5/4, 29)
# (-1/5, 29)
# (-3/10, 34)
# (-5/6, 34)
# (-1/12, 37)
# (-3, 37)
# (-5/8, 41)
# (-2/5, 41)
# (-1/14, 50)
# (-7/2, 50)
# (-1/7, 53)
# (-7/4, 53)
# (-3/14, 58)
# (-7/6, 58)
# (-5/12, 61)
# (-3/5, 61)
# (-2/7, 65)
# (-1/16, 65)
# (-7/8, 65)
# (-4, 65)
# (-4/3, 73)
# (-3/16, 73)
# (-5/14, 74)
# (-7/10, 74)
# (-1/18, 82)
# (-9/2, 82)
# (-3/7, 85)
# (-7/12, 85)
# (-9/4, 85)
# (-1/9, 85)
# (-5/16, 89)
# (-4/5, 89)
# (-9/8, 97)
# (-2/9, 97)
# (-1/20, 101)
# (-5, 101)
# (-5/18, 106)
# (-9/10, 106)
# (-5/3, 109)
# (-3/20, 109)
# (-4/7, 113)
# (-7/16, 113)
# (-1/22, 122)
# (-11/2, 122)
# (-1/11, 125)
# (-11/4, 125)
# (-3/22, 130)
# (-7/18, 130)
# (-9/14, 130)
# (-11/6, 130)
# (-2/11, 137)
# (-11/8, 137)
# (-1/24, 145)
# (-9/16, 145)
# (-4/9, 145)
# (-6, 145)
# (-5/22, 146)
# (-11/10, 146)
# (-5/7, 149)
# (-7/20, 149)
# ...

# %%
c = QQ(-5/2)
X = unfolding.triangulate_gothic1128(c)
f = X.generators_veech
print(f"{c} | {f.chi_orb} | {f.cusps} | {f.genus} | {f.points_orbifold}")
