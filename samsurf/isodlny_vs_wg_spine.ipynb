# %%
from itertools import product, combinations
from collections import deque, defaultdict

from context import samsurf
from triangulation import Triangle, Triangulation
import geom_equiv
from polygon import Point
from halfplane import HalfPlane
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_37405/3531621952.py in <module>
#       3
#       4 from context import samsurf
# ----> 5 from triangulation import Triangle, Triangulation
#       6 import geom_equiv
#       7 from polygon import Point
#
# ~/Dropbox (Brown)/FreedmanPhD/samsurf/samsurf/samsurf/triangulation.py in <module>
#      18 from samsurf.geom_equiv import gen_geom_equivs, is_cut_paste_equiv
#      19
# ---> 20 from samsurf.rational_ht_application import bicuspid_segments, segments_for_plotting
#      21 from samsurf.geom_equiv import gen_geom_equivs
#      22
#
# ~/Dropbox (Brown)/FreedmanPhD/samsurf/samsurf/samsurf/rational_ht_application.py in <module>
#       3 import itertools
#       4 from sage.all import *
# ----> 5 from bowman.linear_xy_poly import LinearXYPoly
#       6 from bowman.cylinder import Cylinder
#       7 from sage.rings.number_field.number_field import is_QuadraticField
#
# ModuleNotFoundError: No module named 'bowman'

# %% [markdown]
# # Messing with the Spine

# %%
def find_trin_good(X):
    r"""
    Find a Delaunay triangulation of ``X`` that permits standard ``gt``-flow for time epsilon.

    .. NOTE:

        This means flowing downward from i in the hyperbolic plane.
    """
    perturb = matrix(AA, [[1, 0], [0, 1 - 1/10_000]])
    if X.apply_matrix(perturb).is_delaunay:
        return X
    r = X.idr
    if any(edge.end == Point(0, 1) for edge in r.polygon.edges):
        idx_edge_ingoing = next(k for k, edge in enumerate(r.polygon.edges) if edge.end == Point(0, 1))
        return find_trin_good(r.get_trin_neighboring(idx_edge_ingoing))
    else:
        # i is interior to an edge of a bad IDR
        rotate = matrix(AA, [[0, -1], [1, 0]])
        return X.apply_matrix(rotate)

# %%
def directions_shortest(X):
    dirns = {}
    for (idx_t, idx_e) in X.idxs_systoles:
        edge = X.triangles[idx_t][idx_e]
        dirn = oo if edge[0] == 0 else edge[1]/edge[0]
        dirns[dirn] = (idx_t, idx_e)
    return dirns

# %%
def systoles_steepest(X):
    steepness_to_systoles = defaultdict(list)
    for idxs in X.idxs_systoles:
        edge = X.triangles[idxs[0]][idxs[1]]
        steepness = oo if edge[0] == 0 else abs(edge[1]/edge[0])
        steepness_to_systoles[steepness].append(idxs)
    steepest = max(steepness_to_systoles)
    return sorted(steepness_to_systoles[steepest])

# %%
def exit_factor(r):
    axis_imag = HalfPlane.from_ineq(0, 1, 0)
    points_intersection = [edge.halfplane.intersect_boundaries(axis_imag) for edge in r.polygon]
    m = min(pt.v2 for pt in points_intersection if pt != oo and pt is not None)
    return sqrt(AA(m))

# %%
def traverse_edge(X, k=1):
    X = find_trin_good(X)
    idxs_systole = systoles_steepest(X)[0]
    next_ups = X.idxs_tying(idxs_systole)
    if not next_ups:
        ef = exit_factor(X.idr)
        X = X.apply_matrix(matrix([[1, 0], [0, ef]]))
        return traverse_edge(X, k * ef)
    else:
        idxs_next_up = next_ups[0]
        k1 = X.contraction_factor(idxs_systole, idxs_next_up)
        m_trans = matrix(AA, [[1, 0], [0, k1]])
        X = X.apply_matrix(m_trans)
        assert len(directions_shortest(X)) > 2
        return k * k1

# %%
def get_neighbors(X0, m0):
    X = X0.apply_matrix(m0).make_delaunay()
    assert len(directions_shortest(X)) > 2
    neighbors = []
    for idxs0, idxs1 in combinations(sorted(directions_shortest(X).values()), r=2):
        edge0, edge1 = X.triangles[idxs0[0]][idxs0[1]], X.triangles[idxs1[0]][idxs1[1]]
        if matrix([edge0, edge1]).determinant() < 0:
            edge0, edge1 = edge1, edge0
        if edge0.dot_product(edge1) > 0:
            edge0, edge1 = -edge1, edge0

        J = matrix(AA, [[0, -1], [1, 0]])
        m_align = matrix(AA, [edge0 + edge1, J*(edge0 + edge1)]).T**(-1)
        X_aligned = X.apply_matrix(m_align)

        if [idxs0, idxs1] == systoles_steepest(X_aligned):
            k = traverse_edge(X_aligned)
            m_total = m_align**(-1) * matrix(AA, [[1, 0], [0, k]]) * m_align * m0
            neighbors.append(m_total)
        elif [idxs0, idxs1] == systoles_steepest(X_aligned.apply_matrix(J)):
            k = traverse_edge(X_aligned.apply_matrix(J))
            m_total = m_align**(-1) * J**(-1) * matrix(AA, [[1, 0], [0, k]]) * J * m_align * m0
            neighbors.append(m_total)
        else:
            continue

    return neighbors

# %%
def explore_spine(X0, num_visited=10):
    visited = set()
    to_visit = deque([identity_matrix(AA, 2)])
    k = 0
    while k < num_visited:
        m = to_visit.pop()
        m.set_immutable()
        visited.add(m)
        for m1 in get_neighbors(X0, m):
            m1.set_immutable()
            if m1 not in visited:
                to_visit.appendleft(m1)
        k += 1
    return visited

# %%
def double_pentagon():
    X = Triangulation.ronen_l(5)
    tris_new = []
    for tri in X.triangles:
        edges_new = [vector(AA, [x, y]) for x, y in tri]
        tris_new.append(Triangle(*edges_new))
    Xint = Triangulation(tris_new, X.gluings)

    [idx_systole] = Xint.idxs_systoles
    [idx_tying] = Xint.idxs_tying(idx_systole)
    k = Xint.contraction_factor(idx_systole, idx_tying)
    Xedge = Xint.apply_matrix(matrix([[1, 0], [0, k]]))

    edge_h, edge_v = Xedge.triangles[2][2], Xedge.triangles[4][0]
    a, b = edge_h + edge_v
    m_norm = matrix([[a, -b], [b, a]])**(-1)
    Xedge = find_trin_good(Xedge.apply_matrix(m_norm))

    idx_sys = Xedge.idxs_systoles[0]
    idx_tying = Xedge.idxs_tying(idx_sys)[0]
    k = Xedge.contraction_factor(idx_sys, idx_tying)
    m_trans = matrix([[1, 0], [0, k]])

    Xvert = Xedge.apply_matrix(m_norm**-1 * m_trans).make_delaunay()
    # tilting one side horizontal
    v, w = Xvert.triangles[5][1], Xvert.triangles[1][1]
    J = matrix(AA, [[0, -1], [1, 0]])
    m = matrix(AA, [-J*(v + w), v + w]).T.inverse()
    return Xvert.apply_matrix(m)

# %%
def main():
    X = double_pentagon()
    print("starting")
    verts = explore_spine(X, 6)

# %prun -D temp.dat main()
# Out:
# starting
#
# *** Profile stats marshalled to file 'temp.dat'.
#          15682373 function calls (15637671 primitive calls) in 26.831 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    206484    3.964    0.000    9.478    0.000 qqbar.py:7806(_interval_fast)
#   1406874    1.997    0.000    1.997    0.000 sets_cat.py:972(_element_constructor_from_element_class)
#    217639    1.536    0.000    3.117    0.000 {method 'polynomial' of 'sage.rings.number_field.number_field_element.NumberFieldElement' objects}
#    170782    1.353    0.000    1.619    0.000 number_field.py:1829(_convert_non_number_field_element)
# 235668/232747    1.198    0.000    1.485    0.000 polynomial_ring.py:309(_element_constructor_)
#      3549    1.115    0.000    1.875    0.001 qqbar.py:7049(_real_refine_interval)
#       732    0.978    0.001    1.399    0.002 number_field.py:10333(_factor_univariate_polynomial)
#    322609    0.954    0.000   11.037    0.000 qqbar.py:3590(__init__)
#    222312    0.938    0.000    5.665    0.000 qqbar.py:8513(an_binop_element)
#       557    0.733    0.001    2.255    0.004 {method 'roots' of 'sage.rings.polynomial.polynomial_element.Polynomial' objects}
#   2456136    0.705    0.000    0.705    0.000 {built-in method builtins.isinstance}
# 214186/212720    0.650    0.000    1.444    0.000 qqbar.py:7520(_interval_fast)
#    173703    0.560    0.000    2.564    0.000 number_field.py:1654(_element_constructor_)
#    130025    0.508    0.000    1.067    0.000 {built-in method _operator.mul}
#     47980    0.504    0.000    0.853    0.000 qqbar.py:5858(interval_exact)
#     98498    0.408    0.000    1.344    0.000 {built-in method _operator.add}
#    322609    0.351    0.000   11.553    0.000 qqbar.py:5279(__init__)
# 52321/31975    0.335    0.000    3.394    0.000 {built-in method builtins.hash}
#    129643    0.247    0.000    7.713    0.000 qqbar.py:3760(_mul_)
#     47980    0.238    0.000    5.079    0.000 qqbar.py:3855(__hash__)
#     97927    0.234    0.000    6.616    0.000 qqbar.py:3807(_add_)
#    492890    0.223    0.000    0.338    0.000 qqbar.py:3008(__richcmp__)
#    229039    0.222    0.000    0.610    0.000 polynomial_ring_constructor.py:676(_single_variate)
#    224821    0.203    0.000    0.363    0.000 qqbar.py:7554(__new__)
#    116636    0.197    0.000    0.234    0.000 qqbar.py:6341(__init__)
#    229047    0.194    0.000    0.331    0.000 polynomial_ring_constructor.py:666(_get_from_cache)
#    117575    0.184    0.000    0.418    0.000 qqbar.py:6409(_interval_fast)
#    202178    0.179    0.000    0.319    0.000 qqbar.py:7560(__init__)
#     35686    0.154    0.000    0.318    0.000 {built-in method _operator.sub}
#     63307    0.142    0.000    0.142    0.000 {built-in method builtins.hasattr}
#    229047    0.137    0.000    0.137    0.000 {method 'get' of 'sage.misc.weak_dict.WeakValueDictionary' objects}
#     53405    0.136    0.000    5.339    0.000 qqbar.py:5356(_richcmp_)
#    505657    0.128    0.000    0.128    0.000 {built-in method sage.structure.richcmp.richcmp}
#      2178    0.126    0.000    2.292    0.001 triangle.py:76(__init__)
#    329109    0.126    0.000    0.168    0.000 qqbar.py:5297(_ensure_real)
#     48102    0.123    0.000    0.177    0.000 qqbar.py:4547(interval_diameter)
#      1872    0.115    0.000    4.369    0.002 triangle.py:221(apply_matrix)
#    207948    0.111    0.000    1.236    0.000 qqbar.py:3171(_interval_fast)
#    202178    0.106    0.000    0.140    0.000 qqbar.py:3025(is_complex)
# 13515/8407    0.104    0.000    0.307    0.000 qqbar.py:3281(super_poly)
#     11341    0.102    0.000    0.282    0.000 polynomial_ring_constructor.py:51(PolynomialRing)
#      6531    0.097    0.000    1.945    0.000 hinge.py:21(__init__)
#    205463    0.096    0.000    0.096    0.000 {method 'to_prec' of 'sage.rings.real_mpfi.RealIntervalField_class' objects}
#    173703    0.095    0.000    0.155    0.000 number_field.py:6679(absolute_polynomial_ntl)
#       861    0.088    0.000    0.153    0.000 {method 'minpoly' of 'sage.rings.number_field.number_field_element.NumberFieldElement_absolute' objects}
#    547666    0.085    0.000    0.085    0.000 {sage.rings.complex_interval.is_ComplexIntervalFieldElement}
#      1089    0.079    0.000    4.336    0.004 hinge.py:166(halfplane)
#      1089    0.079    0.000    2.294    0.002 hinge.py:151(_coefficients)
#     93711    0.076    0.000    0.076    0.000 {method 'diameter' of 'sage.rings.real_mpfi.RealIntervalFieldElement' objects}
#     13085    0.074    0.000    0.308    0.000 polynomial_element_generic.py:1082(__init__)
#     35192    0.074    0.000    2.628    0.000 qqbar.py:3820(_sub_)
#     13923    0.073    0.000    0.362    0.000 free_module.py:1063(_element_constructor_)
# 50213/50049    0.073    0.000    0.802    0.000 qqbar.py:1082(_element_constructor_)
#    132563    0.067    0.000    0.067    0.000 {built-in method sage.rings.real_mpfi.RealIntervalField}
#    211137    0.066    0.000    0.066    0.000 {built-in method __new__ of type object at 0x7fbcd0482980}
#      3697    0.066    0.000    0.098    0.000 {built-in method _operator.truediv}
#      3498    0.066    0.000    2.017    0.001 {method 'determinant' of 'sage.matrix.matrix2.Matrix' objects}
#      4703    0.065    0.000    0.118    0.000 matrix_space.py:815(_element_constructor_)
#    454173    0.064    0.000    0.064    0.000 {method 'precision' of 'sage.rings.real_mpfi.RealIntervalFieldElement' objects}
#       732    0.061    0.000    0.064    0.000 {method '_pari_with_name' of 'sage.rings.polynomial.polynomial_element.Polynomial' objects}
#    173703    0.061    0.000    0.061    0.000 number_field.py:6690(polynomial_ntl)
#    122021    0.058    0.000    0.083    0.000 number_field.py:8181(absolute_polynomial)
#      4349    0.058    0.000    0.136    0.000 matrix_space.py:86(get_matrix_class)
#    369431    0.058    0.000    0.058    0.000 {method 'parent' of 'sage.structure.element.Element' objects}
#      2327    0.056    0.000    1.435    0.001 radical.py:48(__eq__)
#    320933    0.056    0.000    0.056    0.000 qqbar.py:7714(generator)
#     42490    0.051    0.000    0.155    0.000 qqbar.py:8453(an_binop_rational)
#    170782    0.050    0.000    0.092    0.000 gap.py:1615(is_GapElement)
#    322609    0.048    0.000    0.048    0.000 {method 'is_NaN' of 'sage.rings.real_mpfi.RealIntervalFieldElement' objects}
#      4349    0.048    0.000    0.184    0.000 matrix_space.py:509(__classcall__)
#    139313    0.047    0.000    0.047    0.000 {method 'lower' of 'sage.rings.real_mpfi.RealIntervalFieldElement' objects}
#     11349    0.046    0.000    0.046    0.000 {built-in method sage.structure.category_object.normalize_names}
#      6617    0.045    0.000    0.270    0.000 rings.py:930(__getitem__)
#      1457    0.042    0.000    0.095    0.000 qqbar.py:7446(<listcomp>)
#      7099    0.042    0.000    0.045    0.000 free_module.py:2494(zero_vector)
#     12807    0.041    0.000    0.394    0.000 free_module.py:5752(_element_constructor_)
#    140047    0.040    0.000    0.040    0.000 {method 'upper' of 'sage.rings.real_mpfi.RealIntervalFieldElement' objects}
#      1399    0.039    0.000    0.929    0.001 halfplane.py:93(contains_point)
#       824    0.039    0.000    0.557    0.001 qqbar.py:6227(_act_)
#    213261    0.037    0.000    0.037    0.000 {method 'is_rational' of 'sage.rings.number_field.number_field_element.NumberFieldElement' objects}
#      1260    0.037    0.000    0.766    0.001 hinge.py:149(<listcomp>)
#    203642    0.035    0.000    0.035    0.000 qqbar.py:6979(is_complex)
#      2772    0.035    0.000    1.011    0.000 triangle.py:218(vertices)
#      9500    0.034    0.000    0.034    0.000 matrix_space.py:2092(ncols)
#      1326    0.033    0.000    0.070    0.000 sequence.py:77(Sequence)
#      3686    0.032    0.000    0.659    0.000 triangulation.py:1616(<genexpr>)
#         6    0.031    0.005   26.438    4.406 334034446.py:1(get_neighbors)
#     49458    0.030    0.000    0.044    0.000 <frozen importlib._bootstrap>:398(parent)
#      4166    0.029    0.000    0.210    0.000 {method 'change_ring' of 'sage.rings.polynomial.polynomial_element.Polynomial' objects}
#       878    0.028    0.000    0.626    0.001 triangulation.py:1623(contraction_factor)
#      1260    0.027    0.000    2.075    0.002 hinge.py:146(incircle_det)
#      5631    0.027    0.000    0.072    0.000 {method 'derivative' of 'sage.rings.polynomial.polynomial_element.Polynomial' objects}
#    123623    0.025    0.000    0.025    0.000 number_field.py:6711(polynomial)
#       732    0.025    0.000    0.350    0.000 {method '_factor_pari_helper' of 'sage.rings.polynomial.polynomial_element.Polynomial' objects}
#      1457    0.024    0.000    0.208    0.000 qqbar.py:7440(find_fn)
# 13639/12439    0.023    0.000    0.117    0.000 qqbar.py:4518(interval_fast)
#      2772    0.023    0.000    2.363    0.001 triangle.py:228(__hash__)
#     22072    0.022    0.000    0.022    0.000 {method '_rational_' of 'sage.rings.number_field.number_field_element.NumberFieldElement' objects}
# 5066/4078    0.021    0.000    3.834    0.001 qqbar.py:5695(sign)
# 1487/1308    0.021    0.000    0.067    0.000 homset.py:83(Hom)
#      1290    0.020    0.000    0.111    0.000 factorization.py:215(__init__)
#   767/766    0.019    0.000    0.024    0.000 homset.py:582(__init__)
#    128141    0.019    0.000    0.019    0.000 qqbar.py:6420(generator)
#  1336/766    0.019    0.000    0.379    0.000 radical.py:63(__lt__)
#      4166    0.017    0.000    0.091    0.000 polynomial_ring.py:1017(change_ring)
#     11341    0.017    0.000    0.017    0.000 {sage.rings.ring.is_Ring}
#       620    0.017    0.000    0.361    0.001 halfplane.py:100(contains_point_on_boundary)
#      3549    0.017    0.000    1.893    0.001 qqbar.py:7018(refine_interval)
#      1464    0.017    0.000    1.491    0.001 qqbar.py:6786(exactify)
#      2053    0.017    0.000    0.040    0.000 free_module.py:271(FreeModule)
#     48013    0.017    0.000    0.017    0.000 {method 'nextabove' of 'sage.rings.real_mpfr.RealNumber' objects}
#      1067    0.017    0.000    0.336    0.000 triangulation.py:1617(<genexpr>)
#      1290    0.016    0.000    0.022    0.000 factorization.py:618(simplify)
#     23429    0.016    0.000    0.016    0.000 {method 'intersection' of 'sage.rings.real_mpfi.RealIntervalFieldElement' objects}
#       150    0.016    0.000    3.893    0.026 668901569.py:1(systoles_steepest)
#      4205    0.015    0.000    0.352    0.000 {built-in method builtins.sum}
#    103423    0.015    0.000    0.015    0.000 {method 'contains_zero' of 'sage.rings.real_mpfi.RealIntervalFieldElement' objects}
#      1116    0.015    0.000    0.015    0.000 {function Random.seed at 0x7fbccf9e40d0}
#      8388    0.014    0.000    0.072    0.000 copy.py:66(copy)
#     47078    0.014    0.000    0.014    0.000 {method 'overlaps' of 'sage.rings.real_mpfi.RealIntervalFieldElement' objects}
#     49458    0.014    0.000    0.014    0.000 {method 'rpartition' of 'str' objects}
#      2815    0.013    0.000    1.643    0.001 qqbar.py:6867(__init__)
#      6384    0.013    0.000    1.914    0.000 hinge.py:46(from_id_edge)
#       763    0.013    0.000    0.210    0.000 halfplane.py:267(radius2)
#       732    0.013    0.000    1.753    0.002 qqbar.py:7383(exactify)
#      2184    0.012    0.000    0.012    0.000 triangulation.py:44(<setcomp>)
#       788    0.012    0.000    0.044    0.000 {method '__copy__' of 'sage.categories.map.Map' objects}
#     19404    0.012    0.000    0.012    0.000 triangle.py:229(<genexpr>)
#    121/61    0.012    0.000   11.131    0.182 1303380800.py:1(find_trin_good)
#       787    0.012    0.000    0.012    0.000 triangulation.py:1226(<listcomp>)
#      3697    0.011    0.000    0.316    0.000 qqbar.py:3771(_div_)
#      2815    0.011    0.000    0.041    0.000 qqbar.py:6635(__init__)
#     64028    0.011    0.000    0.011    0.000 {method 'precision' of 'sage.rings.real_mpfi.RealIntervalField_class' objects}
#     13119    0.011    0.000    0.090    0.000 {built-in method builtins.any}
#       905    0.011    0.000    0.145    0.000 halfplane.py:263(center)
# 6500/4213    0.011    0.000    0.449    0.000 qqbar.py:4453(_more_precision)
#       826    0.010    0.000    0.583    0.001 qqbar.py:4102(sqrt)
#      6617    0.010    0.000    0.016    0.000 rings.py:1092(normalize_arg)
#       171    0.010    0.000    0.045    0.000 polynomial_ring.py:232(__init__)
#     28874    0.010    0.000    0.010    0.000 triangle.py:158(__getitem__)
#      1439    0.010    0.000    1.912    0.001 triangulation.py:1238(<genexpr>)
#      4700    0.010    0.000    0.013    0.000 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#      2126    0.009    0.000    0.013    0.000 polygon.py:11(__new__)
#       229    0.009    0.000    0.658    0.003 polygon.py:23(CCW)
# 6500/4213    0.009    0.000    0.457    0.000 qqbar.py:5318(_more_precision)
#      1797    0.009    0.000    0.070    0.000 qqbar.py:4367(_set_descr)
#     56636    0.009    0.000    0.009    0.000 {method 'unique_sign' of 'sage.rings.real_mpfi.RealIntervalFieldElement' objects}
#      6617    0.009    0.000    0.009    0.000 rings.py:1130(<listcomp>)
#     31254    0.009    0.000    0.009    0.000 free_module.py:1963(degree)
#      2860    0.008    0.000    1.274    0.000 {built-in method builtins.sorted}
#     20139    0.008    0.000    0.008    0.000 number_field.py:6010(gen)
#     60/30    0.008    0.000   18.371    0.612 4132159543.py:1(traverse_edge)
#       295    0.008    0.000    0.301    0.001 hinge.py:63(<listcomp>)
#       732    0.008    0.000    1.408    0.002 {method 'factor' of 'sage.rings.polynomial.polynomial_element.Polynomial' objects}
#       484    0.008    0.000    2.392    0.005 polygon.py:188(partition_edges)
#      5777    0.008    0.000    0.008    0.000 {method '__copy__' of 'numpy.ndarray' objects}
#       693    0.008    0.000    1.874    0.003 triangulation.py:1234(<listcomp>)
# 9973/8897    0.008    0.000    0.114    0.000 qqbar.py:5846(_interval_fast)
# 4502/3959    0.008    0.000    0.990    0.000 {built-in method builtins.max}
#     11873    0.008    0.000    0.010    0.000 radical.py:16(__iter__)
#      4515    0.008    0.000    0.008    0.000 number_field.py:4234(pari_polynomial)
# 8227/8165    0.007    0.000    0.543    0.000 qqbar.py:3922(__bool__)
#         7    0.007    0.001    3.148    0.450 triangulation.py:1244(make_delaunay)
#       240    0.007    0.000    0.800    0.003 {built-in method builtins.min}
#      2914    0.007    0.000    0.007    0.000 number_field.py:1797(<genexpr>)
#      1326    0.007    0.000    0.028    0.000 sequence.py:406(__init__)
#      2074    0.007    0.000    1.238    0.001 qqbar.py:1344(polynomial_root)
#       121    0.007    0.000    4.935    0.041 triangulation.py:1292(_halfplanes_to_hinges_degenerate)
#      1088    0.007    0.000    0.713    0.001 polygon.py:47(__new__)
#     11387    0.006    0.000    0.006    0.000 {method 'base_ring' of 'sage.rings.polynomial.polynomial_element.Polynomial' objects}
#       118    0.006    0.000    0.017    0.000 free_module.py:752(__init__)
#      3086    0.006    0.000    0.028    0.000 qqbar.py:3333(__call__)
# 5030/1881    0.006    0.000    1.847    0.001 qqbar.py:4349(exactify)
# 27440/26708    0.006    0.000    0.007    0.000 {built-in method builtins.len}
#      2184    0.006    0.000    0.025    0.000 triangulation.py:43(__key)
#       295    0.006    0.000    0.442    0.001 hinge.py:59(is_convex)
#      1671    0.006    0.000    0.361    0.000 qqbar.py:4473(minpoly)
#       147    0.006    0.000    0.382    0.003 hinge.py:120(flip)
# 2756/2311    0.006    0.000    0.069    0.000 qqbar.py:8375(_interval_fast)
#      1116    0.006    0.000    0.028    0.000 rings.py:513(__pow__)
#       734    0.006    0.000    0.218    0.000 qqbar.py:2365(find_zero_result)
#   726/121    0.006    0.000    3.539    0.029 halfplane.py:147(intersect_halfplanes)
#      7623    0.006    0.000    0.006    0.000 hinge.py:41(<genexpr>)
#       557    0.006    0.000    2.267    0.004 qqbar.py:2815(cmp_elements_with_same_minpoly)
#       732    0.006    0.000    0.006    0.000 number_field.py:4297(pari_nf)
#       276    0.006    0.000    2.657    0.010 triangulation.py:1236(is_delaunay)
#      1210    0.006    0.000    0.006    0.000 dynamic_class.py:129(dynamic_class)
#       171    0.005    0.000    0.027    0.000 polynomial_ring.py:655(_coerce_map_from_base_ring)
#   445/126    0.005    0.000    0.189    0.001 qqbar.py:8397(exactify)
#       170    0.005    0.000    0.010    0.000 {method 'coerce_map_from' of 'sage.structure.parent.Parent' objects}
#     11314    0.005    0.000    0.005    0.000 {method '_richcmp_' of 'sage.rings.real_mpfi.RealIntervalFieldElement' objects}
#       787    0.005    0.000    0.017    0.000 triangulation.py:1224(edges)
#     36279    0.005    0.000    0.005    0.000 qqbar.py:2990(__hash__)
#      2632    0.005    0.000    0.010    0.000 misc.py:3376(binomial)
#       732    0.005    0.000    0.014    0.000 {method 'is_monic' of 'sage.rings.polynomial.polynomial_element.Polynomial' objects}
#      1089    0.005    0.000    0.011    0.000 hinge.py:39(coordinates)
#     19755    0.004    0.000    0.004    0.000 {method 'get' of 'dict' objects}
#       312    0.004    0.000    6.059    0.019 triangulation.py:462(apply_matrix)
#         7    0.004    0.001    0.005    0.001 qqbar.py:2260(do_polred)
#       186    0.004    0.000    0.005    0.000 qqbar.py:7834(invert)
#     10087    0.004    0.000    0.004    0.000 {sage.rings.finite_rings.finite_field_base.is_FiniteField}
#     18516    0.004    0.000    0.004    0.000 polynomial_ring_constructor.py:566(<genexpr>)
#      2178    0.004    0.000    0.357    0.000 functional.py:409(symbolic_sum)
#      2632    0.004    0.000    0.004    0.000 {method 'binomial' of 'sage.rings.integer.Integer' objects}
#       294    0.004    0.000    0.018    0.000 special.py:126(column_matrix)
#     19578    0.004    0.000    0.004    0.000 free_module.py:2051(coordinate_ring)
#      2637    0.004    0.000    0.004    0.000 polygon.py:197(<genexpr>)
#      1403    0.004    0.000    0.020    0.000 hinge.py:67(<genexpr>)
#      2184    0.004    0.000    4.373    0.002 triangulation.py:463(<genexpr>)
#      6611    0.004    0.000    0.004    0.000 {method 'split' of 'str' objects}
#      1869    0.004    0.000    0.080    0.000 qqbar.py:3831(_neg_)
#      4962    0.004    0.000    0.004    0.000 weakref.py:353(__init__)
#      1116    0.004    0.000    0.020    0.000 random.py:126(seed)
#       420    0.004    0.000    0.029    0.000 rings.py:383(_Hom_)
#       732    0.004    0.000    0.005    0.000 {method 'sort' of 'list' objects}
#      5292    0.004    0.000    0.006    0.000 triangulation.py:1321(_id_edge_after_flip)
#      5544    0.004    0.000    0.004    0.000 {method 'list' of 'sage.modules.vector_integer_dense.Vector_integer_dense' objects}
#       310    0.004    0.000    1.283    0.004 halfplane.py:126(_intersect_edge_ideal)
#       282    0.004    0.000    0.791    0.003 polygon.py:162(_close_edge_chain)
#      1466    0.004    0.000    0.062    0.000 qqbar.py:7084(<listcomp>)
#       420    0.003    0.000    0.022    0.000 homset.py:39(RingHomset)
#       121    0.003    0.000    0.059    0.000 halfplane.py:310(_intersect_circle)
#       401    0.003    0.000    0.185    0.000 halfplane.py:280(start)
#       865    0.003    0.000    0.157    0.000 qqbar.py:7754(minpoly)
#      2053    0.003    0.000    0.003    0.000 free_module.py:201(create_key)
#      1274    0.003    0.000    0.007    0.000 qqbar.py:7816(neg)
#       147    0.003    0.000    1.326    0.009 triangulation.py:1338(flip_hinge)
#      2641    0.003    0.000    0.007    0.000 qqbar.py:3189(union)
#       147    0.003    0.000    0.010    0.000 triangulation.py:1332(<dictcomp>)
#      1457    0.003    0.000    0.003    0.000 {method 'variable_name' of 'sage.rings.polynomial.polynomial_element.Polynomial' objects}
#      5152    0.003    0.000    0.005    0.000 weakref.py:348(__new__)
#      6631    0.003    0.000    0.003    0.000 factorization.py:319(__getitem__)
#       484    0.003    0.000    3.276    0.007 polygon.py:201(intersect_with_halfplane)
#       732    0.003    0.000    0.024    0.000 qqbar.py:6819(<listcomp>)
#      4840    0.003    0.000    0.005    0.000 functional.py:235(denominator)
#       732    0.003    0.000    0.014    0.000 factorization.py:646(sort)
#      3617    0.003    0.000    0.003    0.000 radical.py:9(__init__)
#      5663    0.003    0.000    0.003    0.000 {sage.rings.polynomial.multi_polynomial_ring_base.is_MPolynomialRing}
#       121    0.003    0.000    8.532    0.071 triangulation.py:1380(idr)
#      1399    0.003    0.000    1.447    0.001 halfplane.py:141(intersect_edge)
#       362    0.003    0.000    0.160    0.000 halfplane.py:290(end)
#      3086    0.003    0.000    0.004    0.000 qqbar.py:4413(_exact_field)
#      6753    0.003    0.000    0.003    0.000 {built-in method builtins.getattr}
#      5292    0.003    0.000    0.003    0.000 hinge.py:181(ids_boundary)
#       480    0.003    0.000    0.421    0.001 qqbar.py:7897(abs)
#       121    0.003    0.000    4.339    0.036 triangulation.py:1294(<listcomp>)
#      4341    0.003    0.000    0.004    0.000 polynomial_ring.py:183(is_PolynomialRing)
#     14237    0.003    0.000    0.003    0.000 {built-in method builtins.iter}
#       464    0.003    0.000    2.378    0.005 triangulation.py:37(__init__)
#       484    0.003    0.000    0.931    0.002 polygon.py:189(<listcomp>)
#      3736    0.003    0.000    0.004    0.000 functional.py:1363(numerator)
#       171    0.003    0.000    0.005    0.000 polynomial_ring.py:1172(gen)
#      2334    0.002    0.000    0.003    0.000 triangle.py:168(__iter__)
#       557    0.002    0.000    0.004    0.000 qqbar.py:2867(<listcomp>)
#       693    0.002    0.000    1.892    0.003 triangulation.py:1232(hinges)
#      9500    0.002    0.000    0.002    0.000 matrix_space.py:2104(nrows)
#      1381    0.002    0.000    2.209    0.002 {built-in method builtins.all}
#       332    0.002    0.000    0.002    0.000 {method 'has_coerce_map_from' of 'sage.structure.parent.Parent' objects}
#        42    0.002    0.000    0.334    0.008 1213626624.py:1(directions_shortest)
#       860    0.002    0.000    0.019    0.000 triangulation.py:52(__eq__)
#       732    0.002    0.000    1.493    0.002 qqbar.py:6844(generator)
#      1593    0.002    0.000    0.003    0.000 number_field.py:5600(degree)
#       324    0.002    0.000    0.006    0.000 rational_field.py:340(_coerce_map_from_)
#      1245    0.002    0.000    0.002    0.000 halfplane.py:271(is_oriented)
# 1030/1020    0.002    0.000    0.003    0.000 category.py:3048(is_subcategory)
#      1089    0.002    0.000    0.840    0.001 hinge.py:43(__hash__)
#      2355    0.002    0.000    0.003    0.000 free_module.py:1129(__richcmp__)
#       173    0.002    0.000    0.003    0.000 polynomial_singular_interface.py:351(can_convert_to_singular)
#      3630    0.002    0.000    0.002    0.000 {built-in method sage.structure.richcmp.rich_to_bool}
# 4487/4485    0.002    0.000    0.003    0.000 {method 'is_zero' of 'sage.structure.element.Element' objects}
#      1290    0.002    0.000    0.002    0.000 factorization.py:303(<listcomp>)
#       315    0.002    0.000    0.003    0.000 fields.py:62(__contains__)
#     11560    0.002    0.000    0.002    0.000 {method 'is_rational' of 'sage.rings.number_field.number_field_element_quadratic.NumberFieldElement_quadratic' objects}
#      4396    0.002    0.000    0.002    0.000 {method 'list' of 'sage.rings.polynomial.polynomial_element.Polynomial_generic_dense' objects}
#       745    0.002    0.000    0.270    0.000 polygon.py:165(<genexpr>)
#      1657    0.002    0.000    0.004    0.000 qqbar.py:8477(an_binop_expr)
#       313    0.002    0.000    0.069    0.000 1303380800.py:13(<genexpr>)
#      1466    0.002    0.000    0.013    0.000 qqbar.py:7099(<listcomp>)
#      6162    0.002    0.000    0.002    0.000 {method 'is_exact' of 'sage.rings.ring.Ring' objects}
#      4170    0.002    0.000    0.002    0.000 {method 'variable_name' of 'sage.structure.category_object.CategoryObject' objects}
#       126    0.002    0.000    0.930    0.007 triangulation.py:1663(<genexpr>)
#      7114    0.002    0.000    0.002    0.000 {built-in method builtins.issubclass}
#      1290    0.002    0.000    0.002    0.000 factorization.py:296(<listcomp>)
#       294    0.002    0.000    0.003    0.000 {method 'transpose' of 'sage.matrix.matrix_dense.Matrix_dense' objects}
#      1399    0.002    0.000    0.006    0.000 {method 'extend' of 'list' objects}
#       158    0.002    0.000    0.366    0.002 triangulation.py:1658(<genexpr>)
#      1754    0.002    0.000    0.002    0.000 qqbar.py:8225(__init__)
#      4900    0.002    0.000    0.002    0.000 polynomial_ring.py:1240(is_sparse)
#       282    0.002    0.000    0.273    0.001 polygon.py:164(is_closed)
#       171    0.002    0.000    0.047    0.000 polynomial_ring.py:1667(__init__)
#       169    0.002    0.000    0.052    0.000 polynomial_ring.py:1957(__init__)
#         8    0.002    0.000    0.007    0.001 number_field.py:249(NumberField)
#       194    0.002    0.000    1.138    0.006 triangulation.py:1604(idxs_systoles)
#       346    0.002    0.000    0.002    0.000 polynomial_ring_constructor.py:671(_save_in_cache)
#       118    0.002    0.000    0.020    0.000 free_module.py:224(create_object)
#      3312    0.002    0.000    0.002    0.000 factorization.py:359(__len__)
#       732    0.002    0.000    0.002    0.000 qqbar.py:6830(<listcomp>)
#       346    0.002    0.000    0.217    0.001 functional.py:1889(sqrt)
#       630    0.002    0.000    0.426    0.001 qqbar.py:3840(__abs__)
#      3086    0.001    0.000    0.002    0.000 qqbar.py:4433(_exact_value)
#        16    0.001    0.000    0.008    0.000 number_field.py:12350(<listcomp>)
#       282    0.001    0.000    0.362    0.001 polygon.py:171(<listcomp>)
#        16    0.001    0.000    0.011    0.001 number_field.py:12215(refine_embedding)
#       174    0.001    0.000    0.032    0.000 unital_algebras.py:71(__init_extra__)
#       118    0.001    0.000    0.005    0.000 modules.py:114(__classcall_private__)
#       732    0.001    0.000    0.002    0.000 factorization.py:571(is_commutative)
#       734    0.001    0.000    0.310    0.000 qqbar.py:7502(_more_precision)
#      4703    0.001    0.000    0.001    0.000 matrix_space.py:1852(is_sparse)
#       147    0.001    0.000    0.002    0.000 triangulation.py:1306(_triangles_after_flip)
#        60    0.001    0.000    0.003    0.000 infinity.py:1118(_element_constructor_)
#      1114    0.001    0.000    0.001    0.000 {method 'union' of 'sage.rings.real_mpfi.RealIntervalFieldElement' objects}
#      1746    0.001    0.000    0.002    0.000 quotient_ring.py:327(is_QuotientRing)
#   870/720    0.001    0.000    0.427    0.001 {built-in method builtins.abs}
#      4287    0.001    0.000    0.001    0.000 {method 'pop' of 'dict' objects}
#       484    0.001    0.000    0.002    0.000 category.py:691(__contains__)
#       251    0.001    0.000    0.110    0.000 halfplane.py:106(intersect_boundaries)
#       824    0.001    0.000    0.001    0.000 {method 'codomain' of 'sage.categories.action.Action' objects}
#      5308    0.001    0.000    0.001    0.000 {method 'values' of 'dict' objects}
#      1089    0.001    0.000    0.160    0.000 halfplane.py:112(_intersect_edge_real)
#       118    0.001    0.000    0.001    0.000 free_module.py:7401(element_class)
#      5761    0.001    0.000    0.001    0.000 {method 'denominator' of 'sage.rings.rational.Rational' objects}
#      4289    0.001    0.000    0.001    0.000 {method 'zero' of 'sage.rings.ring.Ring' objects}
#       558    0.001    0.000    0.016    0.000 random.py:117(__init__)
#       171    0.001    0.000    0.051    0.000 polynomial_ring.py:1786(__init__)
#      1671    0.001    0.000    0.001    0.000 {method 'imag' of 'sage.rings.real_mpfi.RealIntervalFieldElement' objects}
#      4657    0.001    0.000    0.001    0.000 {method 'numerator' of 'sage.rings.rational.Rational' objects}
#   120/119    0.001    0.000    0.008    0.000 category_with_axiom.py:1967(__classcall__)
#       170    0.001    0.000    0.011    0.000 polynomial_ring.py:681(_coerce_map_from_)
#       121    0.001    0.000    0.055    0.000 triangulation.py:1386(<dictcomp>)
#      3940    0.001    0.000    0.001    0.000 {built-in method sage.structure.element.parent}
#      3305    0.001    0.000    0.001    0.000 factorization.py:299(<genexpr>)
#      2823    0.001    0.000    0.001    0.000 {built-in method sage.rings.polynomial.polynomial_element.is_Polynomial}
#   424/423    0.001    0.000    0.018    0.000 homset.py:1231(__init__)
#         1    0.001    0.001   26.452   26.452 355106226.py:1(explore_spine)
#        35    0.001    0.000    0.017    0.000 halfplane.py:235(_intersect_circle)
#       480    0.001    0.000    0.031    0.000 qqbar.py:7876(norm)
#      5682    0.001    0.000    0.001    0.000 {sage.rings.real_mpfi.is_RealIntervalFieldElement}
#       120    0.001    0.000    0.041    0.000 1303380800.py:14(<genexpr>)
#       147    0.001    0.000    0.019    0.000 hinge.py:72(marked_cartesian_coords)
#        93    0.001    0.000    0.001    0.000 {built-in method resource.getrusage}
#       590    0.001    0.000    0.005    0.000 hinge.py:68(<genexpr>)
#         1    0.001    0.001    0.385    0.385 3813917133.py:1(double_pentagon)
#      1457    0.001    0.000    0.001    0.000 factorization.py:708(sort_key)
#      4693    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#       120    0.001    0.000    0.001    0.000 201302489.py:4(<genexpr>)
#        60    0.001    0.000    1.057    0.018 triangulation.py:1347(flip_hinges)
#      6654    0.001    0.000    0.001    0.000 {method 'base_ring' of 'sage.structure.category_object.CategoryObject' objects}
#      3549    0.001    0.000    0.001    0.000 {method 'is_exact' of 'sage.rings.real_mpfi.RealIntervalFieldElement' objects}
#       595    0.001    0.000    0.002    0.000 qqbar.py:6480(neg)
#       861    0.001    0.000    0.001    0.000 rational_field.py:998(characteristic)
#       173    0.001    0.000    0.001    0.000 {method 'register_coercion' of 'sage.structure.parent.Parent' objects}
#       547    0.001    0.000    0.001    0.000 category.py:647(_subcategory_hook_)
#       171    0.001    0.000    0.002    0.000 {method '_populate_coercion_lists_' of 'sage.structure.parent.Parent' objects}
#      3549    0.001    0.000    0.001    0.000 qqbar.py:6723(poly)
#       732    0.001    0.000    0.001    0.000 qqbar.py:6832(factors)
#       422    0.001    0.000    0.018    0.000 homset.py:70(__init__)
#       734    0.001    0.000    0.001    0.000 {method '_pow_int' of 'sage.structure.element.RingElement' objects}
#       107    0.001    0.000    0.010    0.000 halfplane.py:205(start)
#       104    0.001    0.000    0.012    0.000 halfplane.py:211(end)
#      2815    0.001    0.000    0.001    0.000 qqbar.py:6737(is_complex)
#       797    0.001    0.000    0.001    0.000 rational_field.py:1684(is_RationalField)
#      2923    0.001    0.000    0.001    0.000 infinity.py:1107(_repr_)
#       743    0.001    0.000    0.001    0.000 {built-in method sage.structure.element.canonical_coercion}
#       120    0.001    0.000    0.001    0.000 category.py:418(__classcall__)
#        93    0.001    0.000    0.002    0.000 misc.py:281(cputime)
#      2015    0.001    0.000    0.001    0.000 factorization.py:639(<listcomp>)
#       146    0.001    0.000    0.035    0.000 halfplane.py:303(_point_outside)
#        36    0.001    0.000    0.023    0.001 {sage.modules.free_module_element.vector}
#       118    0.001    0.000    0.001    0.000 category.py:2506(category)
#        36    0.001    0.000    0.020    0.001 {method '_algebraic_' of 'sage.rings.number_field.number_field_element.NumberFieldElement' objects}
#        89    0.001    0.000    0.002    0.000 qqbar.py:4571(interval)
#      2760    0.001    0.000    0.001    0.000 {method 'sign' of 'sage.rings.rational.Rational' objects}
#        30    0.001    0.000    0.063    0.002 201302489.py:1(exit_factor)
#       186    0.001    0.000    0.018    0.000 qqbar.py:3790(__invert__)
#       148    0.001    0.000    0.003    0.000 prandom.py:124(randint)
#        62    0.001    0.000    1.913    0.031 triangulation.py:1639(idxs_tying)
#       158    0.001    0.000    0.001    0.000 random.py:290(randrange)
#      1797    0.001    0.000    0.001    0.000 qqbar.py:605(default_interval_prec)
#        43    0.001    0.000    0.013    0.000 halfplane.py:228(_point_outside)
#      1918    0.001    0.000    0.001    0.000 qqbar.py:3085(is_trivial)
#      1399    0.001    0.000    0.001    0.000 polygon.py:63(is_ideal)
#      2928    0.001    0.000    0.001    0.000 {method 'degree' of 'sage.rings.polynomial.polynomial_element.Polynomial_generic_dense' objects}
#        93    0.001    0.000    0.002    0.000 verbose.py:116(verbose)
#      1072    0.001    0.000    0.001    0.000 homset.py:1172(domain)
#       173    0.001    0.000    0.001    0.000 polynomial_ring.py:471(_implementation_names)
#        60    0.001    0.000    0.013    0.000 {method 'dot_product' of 'sage.modules.free_module_element.FreeModuleElement' objects}
#      2668    0.001    0.000    0.001    0.000 {built-in method sage.structure.coerce.py_scalar_to_element}
#      1326    0.001    0.000    0.001    0.000 sequence.py:707(universe)
#      1482    0.001    0.000    0.001    0.000 qqbar.py:2122(prec_seq)
#       307    0.000    0.000    0.000    0.000 halfplane.py:196(is_oriented)
#       147    0.000    0.000    0.010    0.000 triangulation.py:1331(_gluings_after_flip)
#       178    0.000    0.000    0.000    0.000 magmas.py:814(__init_extra__)
#       158    0.000    0.000    0.001    0.000 random.py:237(_randbelow_with_getrandbits)
#      2359    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#      3186    0.000    0.000    0.000    0.000 {method 'real' of 'sage.rings.real_mpfi.RealIntervalFieldElement' objects}
#        32    0.000    0.000    0.001    0.000 {method 'approx' of 'sage.rings.real_lazy.LazyFieldElement' objects}
#       293    0.000    0.000    0.000    0.000 additive_magmas.py:207(__init_extra__)
#         6    0.000    0.000    0.001    0.000 multi_polynomial_ring.py:176(__call__)
#      1071    0.000    0.000    0.000    0.000 homset.py:1187(codomain)
#      2015    0.000    0.000    0.000    0.000 factorization.py:635(<lambda>)
#         1    0.000    0.000   26.838   26.838 4232992546.py:1(main)
#         9    0.000    0.000    0.000    0.000 qqbar.py:3110(pari_field)
#         1    0.000    0.000    0.001    0.001 {sage.rings.number_field.number_field_morphisms.root_from_approx}
#       173    0.000    0.000    0.000    0.000 {method '_make_weak_references' of 'sage.categories.map.Map' objects}
#         7    0.000    0.000    0.001    0.000 qqbar.py:2205(clear_denominators)
#       174    0.000    0.000    0.001    0.000 free_module.py:4763(_coerce_map_from_)
#      1651    0.000    0.000    0.000    0.000 {method 'copy' of 'list' objects}
#       123    0.000    0.000    0.000    0.000 {built-in method sage.rings.ring._is_Field}
#      1127    0.000    0.000    0.000    0.000 {method 'category' of 'sage.rings.ring.Ring' objects}
#       173    0.000    0.000    0.000    0.000 rings.py:334(is_zero)
#         2    0.000    0.000    0.000    0.000 qqbar.py:3235(<listcomp>)
#      1604    0.000    0.000    0.000    0.000 {method 'degree' of 'sage.rings.polynomial.polynomial_rational_flint.Polynomial_rational_flint' objects}
#       111    0.000    0.000    0.040    0.000 halfplane.py:328(_intersect_line)
#      1349    0.000    0.000    0.000    0.000 qqbar.py:7742(field_element_value)
#        90    0.000    0.000    0.001    0.000 qqbar.py:2179(rational_exact_root)
#         7    0.000    0.000    0.001    0.000 qqbar.py:7475(<listcomp>)
#       732    0.000    0.000    0.000    0.000 factorization.py:509(universe)
#       356    0.000    0.000    0.001    0.000 infinity.py:1669(_richcmp_)
#        66    0.000    0.000    0.001    0.000 vector_spaces.py:39(__classcall_private__)
#        60    0.000    0.000    1.058    0.018 idr.py:28(get_trin_neighboring)
#       738    0.000    0.000    0.000    0.000 number_field.py:6076(is_field)
#       148    0.000    0.000    0.001    0.000 prandom.py:60(_pyrand)
#       118    0.000    0.000    0.017    0.000 free_module.py:4703(__init__)
#        63    0.000    0.000    0.011    0.000 qqbar.py:8158(exactify)
#         7    0.000    0.000    0.000    0.000 qqbar.py:7492(intv_fn)
#       121    0.000    0.000    0.000    0.000 idr.py:9(__init__)
#        65    0.000    0.000    0.010    0.000 free_module.py:7384(__init__)
#       148    0.000    0.000    0.001    0.000 random.py:334(randint)
#      1039    0.000    0.000    0.000    0.000 homset.py:747(homset_category)
#       732    0.000    0.000    0.000    0.000 {method 'is_commutative' of 'sage.rings.ring.CommutativeAlgebra' objects}
#       180    0.000    0.000    0.000    0.000 {method 'nth_root' of 'sage.rings.integer.Integer' objects}
#       166    0.000    0.000    0.000    0.000 polynomial_ring.py:1223(is_exact)
#       890    0.000    0.000    0.000    0.000 {built-in method sys.setrecursionlimit}
#       150    0.000    0.000    0.000    0.000 qqbar.py:6508(abs)
#       571    0.000    0.000    0.000    0.000 {method '_rational_' of 'sage.rings.number_field.number_field_element_quadratic.NumberFieldElement_quadratic' objects}
#       351    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         6    0.000    0.000    0.001    0.000 polynomial_ring_constructor.py:754(_multi_variate)
#       118    0.000    0.000    0.018    0.000 free_module.py:5570(__init__)
#         2    0.000    0.000    0.001    0.000 multi_polynomial_ring.py:112(__init__)
#       118    0.000    0.000    0.017    0.000 free_module.py:5400(__init__)
#        63    0.000    0.000    0.000    0.000 qqbar.py:8101(_interval_fast)
#       732    0.000    0.000    0.000    0.000 qqbar.py:3098(field)
#        35    0.000    0.000    0.011    0.000 halfplane.py:296(_point_inside)
#         4    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       310    0.000    0.000    0.000    0.000 {sage.rings.number_field.number_field_base.is_NumberField}
#       173    0.000    0.000    0.000    0.000 polynomial_ring.py:1918(_implementation_names_impl)
#        30    0.000    0.000    0.032    0.001 201302489.py:3(<listcomp>)
#       165    0.000    0.000    0.000    0.000 {method 'is_field' of 'sage.rings.ring.Field' objects}
#         1    0.000    0.000    0.002    0.002 {method 'inverse' of 'sage.matrix.matrix2.Matrix' objects}
#        14    0.000    0.000    0.000    0.000 {method 'factor' of 'sage.rings.integer.Integer' objects}
#       292    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#        63    0.000    0.000    0.000    0.000 qqbar.py:3425(neg)
#         7    0.000    0.000    0.000    0.000 {method 'denominator' of 'sage.rings.polynomial.polynomial_element.Polynomial' objects}
#       588    0.000    0.000    0.000    0.000 hinge.py:137(<genexpr>)
#       588    0.000    0.000    0.000    0.000 hinge.py:131(<genexpr>)
#       173    0.000    0.000    0.000    0.000 {function FreeModule_ambient._coerce_map_from_ at 0x7fbc5bf20700}
#        28    0.000    0.000    0.000    0.000 qqbar.py:6469(minpoly)
#       445    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#         7    0.000    0.000    0.001    0.000 qqbar.py:2316(isolating_interval)
#        14    0.000    0.000    0.000    0.000 term_order.py:570(__init__)
#       148    0.000    0.000    0.000    0.000 {method 'python_random' of 'sage.misc.randstate.randstate' objects}
#        48    0.000    0.000    0.009    0.000 halfplane.py:217(endpoint_real)
#       149    0.000    0.000    0.000    0.000 fraction_field.py:136(is_FractionField)
#         6    0.000    0.000    0.000    0.000 multi_polynomial_element.py:100(__call__)
#        10    0.000    0.000    0.000    0.000 multi_polynomial_element.py:383(__init__)
#        12    0.000    0.000    0.000    0.000 {method 'poly_repr' of 'sage.rings.polynomial.polydict.PolyDict' objects}
#       342    0.000    0.000    0.000    0.000 polynomial_ring.py:1304(ngens)
#        66    0.000    0.000    0.010    0.000 free_module.py:5662(__init__)
#        60    0.000    0.000    0.041    0.001 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 number_field.py:1585(construction)
#       148    0.000    0.000    0.000    0.000 {built-in method sage.misc.randstate.current_randstate}
#         7    0.000    0.000    0.000    0.000 {method '__pari__' of 'sage.rings.polynomial.polynomial_element.Polynomial' objects}
#       121    0.000    0.000    0.000    0.000 triangulation.py:49(__hash__)
#         8    0.000    0.000    0.002    0.000 number_field.py:625(create_key_and_extra_args)
#         1    0.000    0.000    0.012    0.012 triangulation.py:420(ronen_l)
#         4    0.000    0.000    0.001    0.000 polynomial_ring.py:598(flattening_morphism)
#        60    0.000    0.000    0.000    0.000 infinity.py:1291(__init__)
#        63    0.000    0.000    0.000    0.000 qqbar.py:7970(__init__)
#         1    0.000    0.000    0.007    0.007 number_field.py:870(QuadraticField)
#       130    0.000    0.000    0.000    0.000 infinity.py:1659(__hash__)
#         6    0.000    0.000    0.003    0.000 qqbar.py:3237(find_fn)
#         6    0.000    0.000    0.022    0.004 3813917133.py:5(<listcomp>)
#       158    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#        12    0.000    0.000    0.000    0.000 multi_polynomial_element.py:427(_repr_)
#       174    0.000    0.000    0.000    0.000 {method '_is_coercion_cached' of 'sage.structure.parent.Parent' objects}
#         8    0.000    0.000    0.000    0.000 number_field.py:8052(_coerce_map_from_)
#         7    0.000    0.000    0.000    0.000 number_field.py:1999(_Hom_)
#       147    0.000    0.000    0.000    0.000 hinge.py:173(triangle)
#       170    0.000    0.000    0.000    0.000 copy.py:107(_copy_immutable)
#         3    0.000    0.000    0.005    0.002 triangulation.py:344(triangulate_rectangle)
#       175    0.000    0.000    0.000    0.000 {method 'one' of 'sage.rings.ring.Ring' objects}
#        38    0.000    0.000    0.000    0.000 re.py:325(_subx)
#         5    0.000    0.000    0.001    0.000 halfplane.py:221(_point_inside)
#         3    0.000    0.000    0.000    0.000 socket.py:480(send)
#         6    0.000    0.000    0.000    0.000 {method 'dict' of 'sage.rings.polynomial.multi_polynomial_libsingular.MPolynomial_libsingular' objects}
#       236    0.000    0.000    0.000    0.000 {method 'is_commutative' of 'sage.rings.ring.CommutativeRing' objects}
#        14    0.000    0.000    0.000    0.000 sre_parse.py:1054(expand_template)
#         5    0.000    0.000    0.001    0.000 halfplane.py:244(_intersect_line)
#        32    0.000    0.000    0.000    0.000 re.py:289(_compile)
#         8    0.000    0.000    0.000    0.000 latex.py:2214(latex_variable_name)
#       118    0.000    0.000    0.000    0.000 {sage.rings.integer_ring.is_IntegerRing}
#        14    0.000    0.000    0.000    0.000 {method 'denominator' of 'sage.rings.number_field.number_field_element_quadratic.NumberFieldElement_quadratic' objects}
#         2    0.000    0.000    0.000    0.000 infinity.py:319(__pari__)
#         7    0.000    0.000    0.000    0.000 number_field.py:163(is_NumberFieldHomsetCodomain)
#       127    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method '_coerce_map_from_base_ring' of 'sage.rings.polynomial.multi_polynomial_ring_base.MPolynomialRing_base' objects}
#         7    0.000    0.000    0.000    0.000 qqbar.py:2937(__init__)
#        28    0.000    0.000    0.000    0.000 defaults.py:25(variable_names)
#        16    0.000    0.000    0.000    0.000 multi_polynomial_element.py:160(<listcomp>)
#       118    0.000    0.000    0.000    0.000 sets_cat.py:1841(is_finite)
#        30    0.000    0.000    0.000    0.000 polygon.py:152(__iter__)
#       153    0.000    0.000    0.000    0.000 {method 'is_prime_field' of 'sage.rings.ring.Ring' objects}
#         1    0.000    0.000   26.838   26.838 {built-in method builtins.exec}
#        32    0.000    0.000    0.000    0.000 {method 'abs' of 'sage.structure.element.RingElement' objects}
#       147    0.000    0.000    0.000    0.000 hinge.py:177(triangle_opp)
#        16    0.000    0.000    0.000    0.000 sequence.py:505(__getitem__)
#         4    0.000    0.000    0.000    0.000 {method 'minpoly' of 'sage.rings.number_field.number_field_element_quadratic.NumberFieldElement_quadratic' objects}
#         8    0.000    0.000    0.000    0.000 latex.py:2166(latex_varify)
#         3    0.000    0.000    0.000    0.000 special.py:888(identity_matrix)
#        14    0.000    0.000    0.000    0.000 misc.py:2430(factor)
#         2    0.000    0.000    0.000    0.000 vector_space_morphism.py:797(__init__)
#        14    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#        14    0.000    0.000    0.000    0.000 re.py:188(match)
#        12    0.000    0.000    0.000    0.000 term_order.py:997(sortkey_degrevlex)
#       140    0.000    0.000    0.000    0.000 {method 'is_exact' of 'sage.rings.real_mpfi.RealIntervalField_class' objects}
#         2    0.000    0.000    0.000    0.000 {method 'univariate_polynomial' of 'sage.rings.polynomial.multi_polynomial_libsingular.MPolynomial_libsingular' objects}
#         2    0.000    0.000    0.000    0.000 free_module.py:5684(_repr_)
#        52    0.000    0.000    0.000    0.000 {method 'is_field' of 'sage.rings.integer_ring.IntegerRing_class' objects}
#         6    0.000    0.000    0.000    0.000 {method '_coerce_' of 'sage.structure.parent_old.Parent' objects}
#         3    0.000    0.000    0.000    0.000 iostream.py:206(schedule)
#         6    0.000    0.000    0.000    0.000 {method 'findall' of 're.Pattern' objects}
#        20    0.000    0.000    0.000    0.000 infinity.py:1307(_richcmp_)
#        18    0.000    0.000    0.000    0.000 sequence.py:241(<listcomp>)
#        16    0.000    0.000    0.000    0.000 {sage.misc.misc_c.prod}
#         2    0.000    0.000    0.000    0.000 matrix_morphism.py:1615(__init__)
#         2    0.000    0.000    0.000    0.000 iostream.py:500(write)
#         2    0.000    0.000    0.000    0.000 vector_space_homspace.py:246(__call__)
#        14    0.000    0.000    0.000    0.000 re.py:331(filter)
#         3    0.000    0.000    0.000    0.000 qqbar.py:5932(real_number)
#        14    0.000    0.000    0.000    0.000 factorization_integer.py:30(__init__)
#         1    0.000    0.000    0.000    0.000 pushout.py:3681(pushout)
#         2    0.000    0.000    0.000    0.000 pushout.py:4383(construction_tower)
#         2    0.000    0.000    0.000    0.000 free_module_homspace.py:339(identity)
#         1    0.000    0.000    0.000    0.000 unital_algebras.py:169(_coerce_map_from_base_ring)
#         1    0.000    0.000    0.000    0.000 pushout.py:2983(__init__)
#         3    0.000    0.000    0.000    0.000 homset.py:945(_abstract_element_class)
#         4    0.000    0.000    0.000    0.000 term_order.py:1896(__eq__)
#         2    0.000    0.000    0.000    0.000 matrix_morphism.py:75(__init__)
#         8    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#         6    0.000    0.000    0.000    0.000 re.py:233(findall)
#        16    0.000    0.000    0.000    0.000 term_order.py:862(__hash__)
#        10    0.000    0.000    0.000    0.000 multi_polynomial_element.py:74(__init__)
#         4    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#         7    0.000    0.000    0.000    0.000 proof.py:168(get_flag)
#        28    0.000    0.000    0.000    0.000 {method 'nbits' of 'sage.rings.integer.Integer' objects}
#         6    0.000    0.000    0.000    0.000 term_order.py:2006(__getitem__)
#         2    0.000    0.000    0.000    0.000 number_field.py:3445(_repr_)
#         4    0.000    0.000    0.000    0.000 category.py:3025(_subcategory_hook_)
#         1    0.000    0.000    0.000    0.000 free_module.py:3671(_Hom_)
#         8    0.000    0.000    0.000    0.000 re.py:198(search)
#         8    0.000    0.000    0.000    0.000 term_order.py:872(__copy)
#         8    0.000    0.000    0.000    0.000 order.py:61(is_NumberFieldOrder)
#        12    0.000    0.000    0.000    0.000 term_order.py:885(sortkey)
#        28    0.000    0.000    0.000    0.000 {method 'group' of 're.Match' objects}
#         2    0.000    0.000    0.001    0.000 multi_polynomial_ring.py:902(__init__)
#         6    0.000    0.000    0.000    0.000 rational_field.py:927(gen)
#         2    0.000    0.000    0.000    0.000 {method 'degree' of 'sage.rings.polynomial.multi_polynomial_libsingular.MPolynomial_libsingular' objects}
#         2    0.000    0.000    0.000    0.000 {method 'coefficient' of 'sage.rings.polynomial.multi_polynomial_libsingular.MPolynomial_libsingular' objects}
#        38    0.000    0.000    0.000    0.000 {method 'set_immutable' of 'sage.matrix.matrix0.Matrix' objects}
#         1    0.000    0.000    0.000    0.000 pushout.py:1825(__init__)
#        30    0.000    0.000    0.000    0.000 {method 'appendleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#        14    0.000    0.000    0.000    0.000 category.py:3046(<genexpr>)
#         1    0.000    0.000    0.005    0.005 triangulation.py:438(<listcomp>)
#         8    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#        12    0.000    0.000    0.000    0.000 {method 'nonzero_values' of 'sage.rings.polynomial.polydict.ETuple' objects}
#         3    0.000    0.000    0.000    0.000 threading.py:1126(is_alive)
#         1    0.000    0.000    0.000    0.000 rational_field.py:305(construction)
#         2    0.000    0.000    0.000    0.000 {method 'is_integral_domain' of 'sage.rings.polynomial.multi_polynomial_ring_base.MPolynomialRing_base' objects}
#         5    0.000    0.000    0.000    0.000 lazy_format.py:84(__mod__)
#         4    0.000    0.000    0.000    0.000 re.py:203(sub)
#         8    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 free_module_morphism.py:65(__init__)
#         1    0.000    0.000    0.000    0.000 pushout.py:2285(__init__)
#         2    0.000    0.000    0.000    0.000 iostream.py:418(_is_master_process)
#         2    0.000    0.000    0.000    0.000 free_module.py:1367(_eq)
#         1    0.000    0.000    0.000    0.000 free_module.py:855(construction)
#         1    0.000    0.000    0.000    0.000 infinity.py:1687(_neg_)
#         1    0.000    0.000    0.000    0.000 infinity.py:1044(gen)
#         3    0.000    0.000    0.000    0.000 threading.py:1059(_wait_for_tstate_lock)
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 qqbar.py:2908(__init__)
#        14    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'is_field' of 'sage.rings.polynomial.multi_polynomial_ring_base.MPolynomialRing_base' objects}
#         1    0.000    0.000    0.000    0.000 free_module.py:874(_Hom_)
#         1    0.000    0.000    0.000    0.000 {method 'latex_variable_names' of 'sage.structure.category_object.CategoryObject' objects}
#        36    0.000    0.000    0.000    0.000 {method 'parent' of 'sage.structure.sage_object.SageObject' objects}
#        18    0.000    0.000    0.000    0.000 multi_polynomial_element.py:341(element)
#         1    0.000    0.000    0.000    0.000 free_module_homspace.py:268(_matrix_space)
#         7    0.000    0.000    0.000    0.000 qqbar.py:2400(conjugate_expand)
#        12    0.000    0.000    0.000    0.000 term_order.py:2118(is_block_order)
#        12    0.000    0.000    0.000    0.000 {method 'reversed' of 'sage.rings.polynomial.polydict.ETuple' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         3    0.000    0.000    0.000    0.000 iostream.py:96(_event_pipe)
#         9    0.000    0.000    0.000    0.000 {method 'gens' of 'sage.structure.parent_gens.ParentWithGens' objects}
#        16    0.000    0.000    0.000    0.000 {function Sequence_generic.__getitem__ at 0x7fbcaedd3e50}
#        10    0.000    0.000    0.000    0.000 category.py:2578(is_Category)
#        21    0.000    0.000    0.000    0.000 free_module.py:2424(rank)
#         1    0.000    0.000    0.000    0.000 qqbar.py:5983(__float__)
#        25    0.000    0.000    0.000    0.000 {method 'variable_names' of 'sage.structure.category_object.CategoryObject' objects}
#         2    0.000    0.000    0.000    0.000 {method '__copy__' of 'sage.matrix.matrix_generic_dense.Matrix_generic_dense' objects}
#        12    0.000    0.000    0.000    0.000 {method 'emul' of 'sage.rings.polynomial.polydict.ETuple' objects}
#         4    0.000    0.000    0.000    0.000 category.py:2999(super_categories)
#         2    0.000    0.000    0.000    0.000 homset.py:40(__init__)
#         7    0.000    0.000    0.000    0.000 qqbar.py:2432(conjugate_shrink)
#        16    0.000    0.000    0.000    0.000 {method 'gen_image' of 'sage.rings.number_field.number_field_morphisms.NumberFieldEmbedding' objects}
#         1    0.000    0.000    0.000    0.000 homset.py:1156(one)
#         6    0.000    0.000    0.000    0.000 free_module.py:1979(dimension)
#         8    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        12    0.000    0.000    0.000    0.000 {method '_repr_option' of 'sage.rings.real_mpfi.RealIntervalField_class' objects}
#         8    0.000    0.000    0.000    0.000 term_order.py:1849(blocks)
#         2    0.000    0.000    0.000    0.000 iostream.py:437(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 category.py:1776(is_subcategory)
#         8    0.000    0.000    0.000    0.000 term_order.py:2130(is_weighted_degree_order)
#         1    0.000    0.000    0.000    0.000 number_field.py:9680(relative_polynomial)
#         2    0.000    0.000    0.000    0.000 sets_cat.py:944(_element_constructor_)
#         6    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.deque' objects}
#         3    0.000    0.000    0.000    0.000 {method 'precision' of 'sage.rings.real_mpfr.RealField_class' objects}
#        12    0.000    0.000    0.000    0.000 {method 'term_order' of 'sage.rings.polynomial.multi_polynomial_ring_base.MPolynomialRing_base' objects}
#         2    0.000    0.000    0.000    0.000 {method 'coerce_embedding' of 'sage.structure.parent.Parent' objects}
#         4    0.000    0.000    0.000    0.000 pushout.py:4086(<genexpr>)
#         6    0.000    0.000    0.000    0.000 {method 'dict' of 'sage.rings.polynomial.polydict.PolyDict' objects}
#         8    0.000    0.000    0.000    0.000 number_field.py:8169(is_absolute)
#         3    0.000    0.000    0.000    0.000 threading.py:529(is_set)
#         2    0.000    0.000    0.000    0.000 term_order.py:1640(singular_str)
#         8    0.000    0.000    0.000    0.000 {method 'fraction_field' of 'sage.rings.ring.Field' objects}
#         1    0.000    0.000    0.000    0.000 triangulation.py:458(<dictcomp>)
#         6    0.000    0.000    0.000    0.000 {method 'category' of 'sage.structure.parent.Parent' objects}
#         1    0.000    0.000    0.000    0.000 {method 'is_square' of 'sage.rings.integer.Integer' objects}
#         2    0.000    0.000    0.000    0.000 {method 'is_exact' of 'sage.rings.polynomial.multi_polynomial_ring_base.MPolynomialRing_base' objects}
#         8    0.000    0.000    0.000    0.000 {method 'base' of 'sage.structure.category_object.CategoryObject' objects}
#         1    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         8    0.000    0.000    0.000    0.000 {method 'ngens' of 'sage.rings.polynomial.multi_polynomial_ring_base.MPolynomialRing_base' objects}
#         4    0.000    0.000    0.000    0.000 polynomial_ring.py:1227(is_field)
#         2    0.000    0.000    0.000    0.000 homset.py:1253(is_Homset)
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         4    0.000    0.000    0.000    0.000 {method 'nrows' of 'sage.matrix.matrix0.Matrix' objects}
#         2    0.000    0.000    0.000    0.000 free_module_homspace.py:84(is_FreeModuleHomspace)
#         4    0.000    0.000    0.000    0.000 term_order.py:1989(__len__)
#         2    0.000    0.000    0.000    0.000 rational_field.py:253(_repr_option)
#         2    0.000    0.000    0.000    0.000 vector_space_homspace.py:205(is_VectorSpaceHomspace)
#         3    0.000    0.000    0.000    0.000 free_module.py:2331(is_sparse)
#         4    0.000    0.000    0.000    0.000 {sage.structure.element.is_Matrix}
#         2    0.000    0.000    0.000    0.000 {method 'is_mutable' of 'sage.matrix.matrix0.Matrix' objects}
#         2    0.000    0.000    0.000    0.000 term_order.py:1768(singular_moreblocks)
#         1    0.000    0.000    0.000    0.000 {method 'is_square' of 'sage.rings.rational.Rational' objects}
#         4    0.000    0.000    0.000    0.000 {method 'ncols' of 'sage.matrix.matrix0.Matrix' objects}
#         1    0.000    0.000    0.000    0.000 pushout.py:4070(<listcomp>)
#         1    0.000    0.000    0.000    0.000 number_field.py:8157(base_field)
#         2    0.000    0.000    0.000    0.000 homsets.py:313(is_endomorphism_set)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 sets_cat.py:1434(construction)
#         1    0.000    0.000    0.000    0.000 pushout.py:4071(<listcomp>)
