# %% [markdown]
# # Samsurf demo, Orsay 2022-03-17

# %%
from triangulation import Triangulation

# %% [markdown]
# ## A triangulation of the regular octagon

# %% [markdown]
# This is built in.

# %%
X = Triangulation.regular_octagon()
X
# Out:
# Triangulation with 6 triangles

# %%
X.plot()
# Out:
# Graphics object consisting of 30 graphics primitives

# %% [markdown]
# ## Fundamental domain for the Veech group

# %%
fd = X.generators_veech
fd
# Out:
# FundDom with 2 idrs and 2 gens

# %%
F = fd.plot()
F.show()
# Out:
# Graphics object consisting of 12 graphics primitives

# %% [markdown]
# ## Random exploration of methods

# %%
X.regular_octagon().regular_octagon().regular_octagon()
# Out:
# Triangulation with 6 triangles

# %%
X.code_comb
# Out:
# -8007698733078716247

# %%
X.code_geom
# Out:
# 164669868039382662

# %%
X.compute_candidate_periodic_points()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_892/2532719571.py in <module>
# ----> 1 X.compute_candidate_periodic_points()
#
# TypeError: compute_candidate_periodic_points() missing 2 required positional arguments: 'tri_id' and 'veech_elem'

# %%
X.triangles
# Out:
# (Triangle(v0=(1, 0), v1=(1/2*a, 1/2*a), v2=(-1/2*a - 1, -1/2*a),
#  Triangle(v0=(-1, 0), v1=(-1/2*a, -1/2*a), v2=(1/2*a + 1, 1/2*a),
#  Triangle(v0=(0, 1), v1=(-1/2*a - 1, -1/2*a - 1), v2=(1/2*a + 1, 1/2*a),
#  Triangle(v0=(0, -1), v1=(1/2*a + 1, 1/2*a + 1), v2=(-1/2*a - 1, -1/2*a),
#  Triangle(v0=(1/2*a, -1/2*a), v1=(1/2*a + 1, 1/2*a + 1), v2=(-a - 1, -1),
#  Triangle(v0=(-1/2*a, 1/2*a), v1=(-1/2*a - 1, -1/2*a - 1), v2=(a + 1, 1))

# %%
X.edges
# Out:
# [(0, 0), (0, 1), (0, 2), (1, 2), (2, 0), (2, 1), (3, 1), (4, 0), (4, 2)]

# %%
XD = X.make_delaunay()

# %%
XD
# Out:
# Triangulation with 6 triangles

# %%
XD.plot()
# Out:
# Graphics object consisting of 30 graphics primitives

# %%
X1 = X.apply_gt_flow(1)

# %%
X1
# Out:
# Triangulation with 6 triangles

# %%
X1.plot()
# Out:
# Graphics object consisting of 30 graphics primitives

# %%
X1D = X1.make_delaunay()

# %%
X1D.plot()
# Out:
# Graphics object consisting of 30 graphics primitives
